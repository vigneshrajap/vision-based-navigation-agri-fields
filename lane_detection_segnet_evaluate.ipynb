# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/image-segmentation-keras")
import keras_segmentation
import matplotlib.pyplot as plt
from keras_segmentation.data_utils.data_loader import get_image_arr , get_segmentation_arr
from keras_segmentation.predict import predict
from keras_segmentation import metrics
from keras_segmentation.predict import model_from_checkpoint_path
import numpy as np
from tqdm import tqdm 
import glob

def evaluate( model=None , inp_images=None , annotations=None , checkpoints_path=None ):
    #Finished implementation of the evaluate function in keras_segmentation.predict
    #Input: array of paths or nd arrays
    if model is None and ( not checkpoints_path is None ):
        model = model_from_checkpoint_path(checkpoints_path)
        
    ious = []
    for inp , ann   in tqdm(zip( inp_images , annotations )):
        pr = predict(model , inp )
        gt = get_segmentation_arr( ann , model.n_classes ,  model.output_width , model.output_height, no_reshape=True)
        gt = gt.argmax(-1)
        iou = metrics.get_iou( gt , pr , model.n_classes )
        ious.append( iou )
    ious = np.array( ious )
    print("Class wise IoU "  ,  np.mean(ious , axis=0 ))
    print("Total  IoU "  ,  np.mean(ious ))

model_path = "/content/drive/My Drive/Colab Notebooks/resnet50_segnet_weights/resnet50_segnet"
inp_dir = "/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/"
ann_dir = "/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/annotations_prepped_test/"

im_files = glob.glob(os.path.join(inp_dir, '*.png'))

ann_files = glob.glob(os.path.join(ann_dir , '*.png'))

print('Running evaluation on ',len(im_files),'images, and',len(ann_files),'annotations:')
print('Images: ', im_files, 'Annotations:', ann_files) 


evaluate(model=None , inp_images= im_files , annotations= ann_files, checkpoints_path=model_path)
# Out:
# ('Running evaluation on ', 60, 'images, and', 60, 'annotations:')
# ('Images: ', ['/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51500.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62275.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_63050.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_11350.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_41685.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_20620.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62990.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30300.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_10000.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30420.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51800.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62900.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_11450.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_20575.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62780.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_20815.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30100.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30680.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_41760.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_41390.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51720.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_20660.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_10320.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_11650.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_20550.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_50950.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30170.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_10810.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_41335.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30890.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_63120.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51650.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62670.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51300.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_10540.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_62855.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30370.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30560.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_30965.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_41710.png', '/content/drive/My Drive/Colab Notebooks/Frogn_Dataset_32x/images_prepped_test/frogn_51760.png', '/content ...
# W0924 13:03:12.049676 140574100658048 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step
# 94666752/94653016 [==============================] - 1s 0us/step
# ('loaded weights ', '/content/drive/My Drive/Colab Notebooks/resnet50_segnet_weights/resnet50_segnet.6')
#   0%|          | 0/60 [00:00<?, ?it/s]
#   2%|▏         | 1/60 [00:02<02:34,  2.62s/it]
#   3%|▎         | 2/60 [00:04<02:14,  2.32s/it]
#   5%|▌         | 3/60 [00:05<02:00,  2.12s/it]
#   7%|▋         | 4/60 [00:07<01:50,  1.97s/it]
#   8%|▊         | 5/60 [00:09<01:42,  1.86s/it]
#  10%|█         | 6/60 [00:10<01:36,  1.79s/it]
#  12%|█▏        | 7/60 [00:12<01:31,  1.73s/it]
#  13%|█▎        | 8/60 [00:13<01:27,  1.69s/it]
#  15%|█▌        | 9/60 [00:15<01:24,  1.66s/it]
#  17%|█▋        | 10/60 [00:17<01:22,  1.64s/it]
#  18%|█▊        | 11/60 [00:18<01:20,  1.64s/it]
#  20%|██        | 12/60 [00:20<01:18,  1.63s/it]
#  22%|██▏       | 13/60 [00:21<01:16,  1.62s/it]
#  23%|██▎       | 14/60 [00:23<01:14,  1.62s/it]
#  25%|██▌       | 15/60 [00:25<01:12,  1.62s/it]
